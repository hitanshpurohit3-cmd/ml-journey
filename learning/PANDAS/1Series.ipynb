# %% [raw]
# PANDAS SERIES
# A Series is a one-dimensional labeled array capable of holding any data type. The axis labels are collectively called the index.
# Series is a verticals and arrays are horizontals.

# %% [raw]
# Creating a Series
# There are multiple ways to create a Series.

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'m':10,'n':20,'o':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
#for custom labels
pd.Series(my_list,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#when we pass dictionary we get key instead of indexes/labels
pd.Series(d)
# Out:
# m    10
# n    20
# o    30
# dtype: int64
