# %%
import numpy as np
import pandas as pd

# %% [raw]
# GroupBy

# %%
data = {
    'Category': ['A','B','A','B','A','B','A','B'],
    'Store': ['S1','S1','S2','S2','S1','S2','S2','S1'],
    'Sales': [100,200,150,250,120,180,200,300],
    'Quantity': [10,15,12,18,8,20,15,25],
    'Date': pd.date_range('2023-01-01',periods = 8)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
#Question- GroupBy Category and calculate the sales
cat = df.groupby('Category')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
#Question GroupBy Store and calculate the sales
cat2 = df.groupby('Store')['Sales'].sum()
cat
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
#Groupby multiple columns
#Groupby Category and store
cat3 = df.groupby(['Category','Store'])['Sales'].sum()
cat3
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %% [raw]
# Aggregation

# %%
df['Sales'].mean()
# Out:
# np.float64(187.5)

# %%
df['Sales'].min()
# Out:
# 100

# %%
df['Sales'].max()#median,avg,std
# Out:
# 300

# %%
df['Sales'].agg(['mean','max','mode','min'])
