# %% [raw]
# DATAFRAME
# dataframe is basically the combination of the Series.

# %%
import numpy as np
import pandas as pd

# %% [raw]
# Creating a DataFrame

# %%
#using Dictionary
data = {
    'Name' : ['John','Anna','Peter','Linda'],
    'Age' : [28,34,29,42],
    'City' : ['New York','Paris','Berlin','London'],
    'Salary' : [65000,70000,62000,85000,]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#using the list
data_list = [
    ['John',28,'New York',65000],
    ['Anna',34,'Paris',70000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',85000],
]

# %%
dfl = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
dfl2 = pd.DataFrame(data_list,columns = columns)

# %%
dfl
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
dfl2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [raw]
# Selection and indexing of columns

# %%
#in data frames column names matter and not he indexing. to target columns we have to write the column name
dfl2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: City, dtype: object

# %%
#for targeting multiple columns we pass a list of list
dfl2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [raw]
# Creating a new column

# %%
dfl2['Designation'] = ['Doctor','Engineer','Doctor','Engineer']

# %%
dfl2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000    Engineer

# %% [markdown]
# dfl2

# %% [raw]
# Removing Columns

# %%
dfl2.drop('Designation',axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#for removing multiple(but remember that this only creates the view and does not remove it from teh orginal dataframe.for slving this using ",inplace=True")

dfl2.drop(['Designation','Age'],axis=1)
# Out:
#     Name      City  Salary
# 0   John  New York   65000
# 1   Anna     Paris   70000
# 2  Peter    Berlin   62000
# 3  Linda    London   85000

# %%
#similarly for removing the  row change axis =1 to axis =0 or don't give the value of axis
dfl2.drop(0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 2  Peter   29  Berlin   62000      Doctor
# 3  Linda   42  London   85000    Engineer

# %% [raw]
# Selecting Rows

# %%
dfl2.loc[0]
# Out:
# Name               John
# Age                  28
# City           New York
# Salary            65000
# Designation      Doctor
# Name: 0, dtype: object

# %%
dfl2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000      Doctor
# 1  Anna   34     Paris   70000    Engineer

# %%
dfl2.iloc[3] #uses index
# Out:
# Name              Linda
# Age                  42
# City             London
# Salary            85000
# Designation    Engineer
# Name: 3, dtype: object

# %% [raw]
# Selecting Subsets of Rows and Columns

# %%
dfl2.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %% [raw]
# Conditional Selection

# %%
dfl2[dfl2["Age"]>30]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000    Engineer
# 3  Linda   42  London   85000    Engineer

# %%
dfl2[dfl2["Age"]>30 & dfl2["City"]=="Paris"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File F:\miniconda\envs\ds_env\lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File F:\miniconda\envs\ds_env\lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...
