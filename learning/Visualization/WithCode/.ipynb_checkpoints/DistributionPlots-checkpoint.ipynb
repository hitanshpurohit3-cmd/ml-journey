# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# We usee distribution plot to visualize the distribution of quntitative data.
# Let's discus some plots that allow us to visualize the distribution of a dataset. These plots are:
# * distplot/histplot
# * jointplot
# * pairplot
# * rugplot

# %% [markdown]
# Distribution plots
# * these are created for quantitative variable(example -> Age,salary and not gender)

# %%
dataset = sns.load_dataset('tips')

# %%
dataset['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %% [markdown]
# in the above loaded tips dataset from seaborn we can clearly observe that:
# - Qualitative:
#     * sex
#     * smoker
#     * day
#     * time
#     * size
# - Quantitative:
#     * total_bill
#     * tip

# %% [markdown]
# So here we can make distribution plots from only the Quantitative variables which are total_bill and tip and else all will be Qualtitative variables which are ploted with categorical plots

# %%
sns.displot(dataset['total_bill'])

# %%
sns.displot(dataset['total_bill'],bins = 6)

# %%
sns.histplot(dataset['total_bill'],bins =6, kde = True )#kde is kernel density estimator
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(dataset['total_bill'],bins = 20,  kde = True)
plt.subplot(1,2,2)
sns.histplot(dataset['tip'],bins = 20, kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
dataset['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %% [markdown]
# JointPlot
# - it has one advantage over displot/histplot is that we can compare two quantitative variables on the same plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset)#bydefault scatter kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'scatter')#scatter kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'kde')#kernel density estimation kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'hex')#hexagon kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'reg')#regression kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'resid')#resid kind

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = dataset, kind = 'hist')#histogram kind

# %% [markdown]
# Pairplot(very important)

# %%
sns.pairplot(dataset)

# %%
sns.pairplot(dataset, hue = 'sex')

# %%
sns.pairplot(dataset, hue='size', palette ='rainbow')

# %% [markdown]
# Rugplot

# %%
sns.rugplot(dataset['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(dataset)
# Out:
# <Axes: >
